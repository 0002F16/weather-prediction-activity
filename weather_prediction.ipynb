# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.tree import DecisionTreeClassifier
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Load and Prepare Data
print("Loading dataset...")
df = pd.read_csv('seattle-weather.csv')

# Separate features from target
# Features: precipitation, temp_max, temp_min, wind
# Target: weather
X = df[['precipitation', 'temp_max', 'temp_min', 'wind']]
y = df['weather']
# Out:
# Loading dataset...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load and Prepare Data
#       2 print("Loading dataset...")
# ----> 3 df = pd.read_csv('seattle-weather.csv')
#       5 # Separate features from target
#       6 # Features: precipitation, temp_max, temp_min, wind
#       7 # Target: weather
#       8 X = df[['precipitation', 'temp_max', 'temp_min', 'wind']]
#
# NameError: name 'pd' is not defined

# %%
# Split Data
print("Splitting data into training and testing sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Train Model
print("Training Decision Tree Classifier...")
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# %%
# Make Predictions
print("Making predictions on test data...")
y_pred = clf.predict(X_test)

# %%
# Evaluate Model
print("\n" + "="*50)
print("MODEL EVALUATION")
print("="*50)

# Calculate and print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")

# Generate and print confusion matrix
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test, y_pred)
print(cm)

# Print confusion matrix with labels for better readability
print("\nConfusion Matrix (with labels):")
labels = sorted(y_test.unique())
print(f"{'':<12}", end="")
for label in labels:
    print(f"{label:<12}", end="")
print()

for i, label in enumerate(labels):
    print(f"{label:<12}", end="")
    for j in range(len(labels)):
        print(f"{cm[i][j]:<12}", end="")
    print()
